# %% [markdown]
# #**Medical Insurance Cost Analysis**

# %% [markdown]
# In this case study we ar analyzing the how the charges should paid by a patient in a month basing other certain values like he is smoker or not.

# %% [markdown]
# ## **Exploring dataset**

# %% [markdown]
# **our data set consists of different columns for prediction of medical insurance**

# %% [markdown]
# ![ds.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Import all required libraries
# example :pandas,numpy etc.

# %%
import pandas as pd
import numpy as np

#visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Linear Regression
from scipy.stats import linregress

#Train_test_split
from sklearn.model_selection import train_test_split

#cross_val_score
from sklearn.model_selection import cross_val_score

#scaling
from sklearn.preprocessing import StandardScaler



from sklearn.model_selection import train_test_split

from sklearn.metrics import precision_score,recall_score, confusion_matrix, classification_report,accuracy_score, f1_score
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score 
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer

import numpy as np
import scipy.stats as st

# %% [markdown]
# imported all required libraries

# %% [markdown]
# ##**Load Dataset**

# %%
#Importing data
df = pd.read_csv("https://github.com/KrishnachaithanyaThummala/Data-Science/blob/main/insurance%20(1).csv?raw=True")

# %% [markdown]
# loading the dataset using the pd.read_csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**Pre_Processing**

# %%
df.head(5)
# Out:
#     age     sex     bmi children smoker     region      charges
# 0  19.0  female  27.900        0    yes  southwest  16884.92400
# 1  18.0    male  33.770        1     no  southeast   1725.55230
# 2  28.0    male  33.000        3     no  southeast   4449.46200
# 3  33.0    male  22.705        0     no  northwest  21984.47061
# 4  32.0    male  28.880        0     no  northwest   3866.85520

# %% [markdown]
#  displaying the top 5 rows from the dataset

# %%
df.tail(5)
# Out:
#        age     sex     bmi children smoker     region      charges
# 1336  21.0  female  25.800        0     no  southwest   2007.94500
# 1337  61.0  female  29.070        0    yes  northwest  29141.36030
# 1338  23.0  female  33.400        0     no  southwest  10795.93733
# 1339  19.0  female  34.700        2    yes  southwest  36397.57600
# 1340  53.0  female  24.795        1     no  northwest  10942.13205

# %% [markdown]
#  displaying the bottom 5 rows from the dataset

# %%
df.sample(3)
# Out:
#       age     sex    bmi children smoker     region     charges
# 232  19.0  female  17.80        0     no  southwest   1727.7850
# 841  59.0    male  24.70        0     no  northeast  12323.9360
# 728  18.0  female  40.28        0     no  northeast   2217.6012

# %% [markdown]
# Randomly 3 rows will display from dataset,by default it will only display the 1 row randomly from dataset

# %%
df.shape
# Out:
# (1341, 7)

# %% [markdown]
# Dispalying numbers rows and columns

# %% [markdown]
# Our dataframe contains 1341 rows and 7 columns

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# It will return the column labels of the given dataframe

# %% [markdown]
# Inorder to predict the medical charges these are the columns provided

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1341, step=1)

# %% [markdown]
# It will helps us to know the total number of rows, where it starts and ends,we can also know about the increment of index from one row to another

# %%
df.dtypes
# Out:
# age         float64
# sex          object
# bmi         float64
# children     object
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# Printing the datatypes of columns labels from the dataframe

# %% [markdown]
# ## Setting index as patient id.

# %%
id=[i+1 for i in range(len(df.index))]
df['patient_id']=id
df.head(5)
# Out:
#     age     sex     bmi children smoker     region      charges  patient_id
# 0  19.0  female  27.900        0    yes  southwest  16884.92400           1
# 1  18.0    male  33.770        1     no  southeast   1725.55230           2
# 2  28.0    male  33.000        3     no  southeast   4449.46200           3
# 3  33.0    male  22.705        0     no  northwest  21984.47061           4
# 4  32.0    male  28.880        0     no  northwest   3866.85520           5

# %% [markdown]
# here we are creating new column patient id and giving the data into it using ‘’id’’

# %%
df.set_index('patient_id',inplace=True)
df.head(5)
# Out:
#              age     sex     bmi children smoker     region      charges
# patient_id
# 1           19.0  female  27.900        0    yes  southwest  16884.92400
# 2           18.0    male  33.770        1     no  southeast   1725.55230
# 3           28.0    male  33.000        3     no  southeast   4449.46200
# 4           33.0    male  22.705        0     no  northwest  21984.47061
# 5           32.0    male  28.880        0     no  northwest   3866.85520

# %% [markdown]
# here we are setting the patient id as index for the dataset df.

# %% [markdown]
# infographics of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1341 entries, 1 to 1341
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1339 non-null   float64
#  1   sex       1340 non-null   object
#  2   bmi       1339 non-null   float64
#  3   children  1341 non-null   object
#  4   smoker    1339 non-null   object
#  5   region    1339 non-null   object
#  6   charges   1340 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 83.8+ KB

# %% [markdown]
# To get a quick overview of the dataset we use this function , we can get the column name, count not null values in a specified column,and datatype of the column

# %%
df.describe()
# Out:
#                age          bmi       charges
# count  1339.000000  1339.000000   1340.000000
# mean     39.174010    30.675747  13266.041263
# std      14.057975     6.088311  12099.759929
# min      18.000000    15.960000   1121.873900
# 25%      26.000000    26.302500   4744.325050
# 50%      39.000000    30.400000   9388.753650
# 75%      51.000000    34.700000  16604.302645
# max      64.000000    53.130000  63770.428010

# %% [markdown]
# is used to view some basic statistical details like percentile, mean, std etc. of a data frame

# %% [markdown]
# ***Here count returns Non-null values***

# %%
df.loc[:,['age','bmi']]
# Out:
#              age     bmi
# patient_id
# 1           19.0  27.900
# 2           18.0  33.770
# 3           28.0  33.000
# 4           33.0  22.705
# 5           32.0  28.880
# ...          ...     ...
# 1337        21.0  25.800
# 1338        61.0  29.070
# 1339        23.0  33.400
# 1340        19.0  34.700
# 1341        53.0  24.795
#
# [1341 rows x 2 columns]

# %% [markdown]
# using loc function we can display data present in the particular column or rows using the labels

# %%
df.iloc[25,:]
# Out:
# age                59
# sex            female
# bmi             27.72
# children            3
# smoker             no
# region      southeast
# charges       14001.1
# Name: 26, dtype: object

# %% [markdown]
#  iloc is integer position-based, so you have to specify rows and columns by their integer position values

# %% [markdown]
# ## Miscategorized values

# %%
df.dtypes
# Out:
# age         float64
# sex          object
# bmi         float64
# children     object
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# Printing the datatypes of columns labels from the dataframe

# %%
df['children'].value_counts()
# Out:
# 0      575
# 1      325
# 2      240
# 3      156
# 4       25
# 5       18
# no       1
# yes      1
# Name: children, dtype: int64

# %% [markdown]
# using  value of counts function we can get the sum of all unique data in a particular column

# %%
df['age'] = df['age'].replace(r'[A-Za-z]+', np.nan, regex = True) 
df['sex'] = df['sex'].replace(r'[0-9]+', np.nan, regex = True)
df['bmi'] = df['bmi'].replace(r'[A-Za-z]+', np.nan, regex = True) 
df['children'] = df['children'].replace(r'[A-Za-z]+', np.nan, regex = True) 
df['smoker'] = df['smoker'].replace(r'[0-9]+', np.nan, regex = True)
df['region'] = df['region'].replace(r'[0-9]+', np.nan, regex = True)
df['charges'] = df['charges'].replace(r'[A-Za-z]+', np.nan, regex = True)

# %% [markdown]
# replacing all miscategorised values present in the dataset with null values

# %%
df['children'].value_counts()
# Out:
# 0    575
# 1    325
# 2    240
# 3    156
# 4     25
# 5     18
# Name: children, dtype: int64

# %% [markdown]
# So we can say that we have removed all the miscategorized values

# %% [markdown]
# **checking for duplicates**

# %%
df.duplicated()
# Out:
# patient_id
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1337    False
# 1338    False
# 1339     True
# 1340     True
# 1341     True
# Length: 1341, dtype: bool

# %% [markdown]
# helps in analyzing duplicate values only. It returns a boolean series which is True only for Unique elements

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# dropping the duplicates present in the dataset

# %% [markdown]
# ## null values

# %%
df.notna()
# Out:
#              age    sex   bmi  children  smoker  region  charges
# patient_id
# 1           True   True  True      True    True    True     True
# 2           True   True  True      True    True    True     True
# 3           True   True  True      True    True    True     True
# 4           True   True  True      True    True    True     True
# 5           True   True  True      True    True    True     True
# ...          ...    ...   ...       ...     ...     ...      ...
# 1334        True  False  True      True    True    True     True
# 1335        True   True  True      True    True    True     True
# 1336        True   True  True      True    True    True     True
# 1337        True   True  True      True    True    True     True
# 1338        True   True  True      True    True    True     True
#
# [1337 rows x 7 columns]

# %% [markdown]
# finding the null values in dataset, whereever there is null value it returns false boolean value

# %% [markdown]
# ## **Finding count of missing values in each column**

# %%
df.isnull().sum()
# Out:
# age         2
# sex         1
# bmi         2
# children    2
# smoker      3
# region      2
# charges     1
# dtype: int64

# %% [markdown]
# total count of null values pressent in the each column

# %%
df.isnull().sum().sum()
# Out:
# 13

# %% [markdown]
# total number of null values present in the entire dataset

# %%
df['smoker'].value_counts()
# Out:
# no     1060
# yes     274
# Name: smoker, dtype: int64

# %% [markdown]
# by this we can say that total no.of smokers and non-smokers present

# %%
df['sex'].value_counts()
# Out:
# male      674
# female    662
# Name: sex, dtype: int64

# %% [markdown]
# counting total no.of male and female present in the dataset

# %% [markdown]
# ##Filling null values with appropriate values

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
val= imputer.fit_transform(np.array(df['smoker']).reshape(-1,1))

val=pd.DataFrame(val)
for i in range(1,len(val)+1):
  df.loc[i,'smoker']=val.iloc[i-1,0]
df['smoker'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# age         3
# sex         2
# bmi         3
# children    3
# smoker      0
# region      3
# charges     2
# dtype: int64

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
val= imputer.fit_transform(np.array(df['sex']).reshape(-1,1))

val=pd.DataFrame(val)
for i in range(1,len(val)+1):
  df.loc[i,'sex']=val.iloc[i-1,0]
df['sex'].isnull().sum()
# Out:
# 0

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
val= imputer.fit_transform(np.array(df['region']).reshape(-1,1))

val=pd.DataFrame(val)
for i in range(1,len(val)+1):
  df.loc[i,'region']=val.iloc[i-1,0]
df['region'].isnull().sum()
# Out:
# 0

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
val= imputer.fit_transform(np.array(df['children']).reshape(-1,1))

val=pd.DataFrame(val)
for i in range(1,len(val)+1):
  df.loc[i,'children']=val.iloc[i-1,0]
df['children'].isnull().sum()
# Out:
# 0

# %% [markdown]
# filling the nan values present in the sex,region,smoker,children columns with most repeated values and checking whether values replaced or not.

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
val= imputer.fit_transform(np.array(df['age']).reshape(-1,1))

val=pd.DataFrame(val)
for i in range(1,len(val)+1):
  df.loc[i,'age']=val.iloc[i-1,0]
df['age'].isnull().sum()
# Out:
# 0

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
val= imputer.fit_transform(np.array(df['bmi']).reshape(-1,1))

val=pd.DataFrame(val)
for i in range(1,len(val)+1):
  df.loc[i,'bmi']=val.iloc[i-1,0]
df['bmi'].isnull().sum()
# Out:
# 0

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
val= imputer.fit_transform(np.array(df['charges']).reshape(-1,1))

val=pd.DataFrame(val)
for i in range(1,len(val)+1):
  df.loc[i,'charges']=val.iloc[i-1,0]
df['charges'].isnull().sum()
# Out:
# 0

# %% [markdown]
# filling the nan values present in the age,bmi,children columns with mean and median because these column are numerical data and checking whether values replaced or not.

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#              age     sex        bmi children smoker     region       charges
# patient_id
# 1           19.0  female  27.900000        0    yes  southwest  16884.924000
# 2           18.0    male  33.770000        1     no  southeast   1725.552300
# 3           28.0    male  33.000000        3     no  southeast   4449.462000
# 4           33.0    male  22.705000        0     no  northwest  21984.470610
# 5           32.0    male  28.880000        0     no  northwest   3866.855200
# ...          ...     ...        ...      ...    ...        ...           ...
# 1335        18.0  female  36.850000        0     no  southeast   1629.833500
# 1336        21.0  female  25.800000        0     no  southwest   2007.945000
# 1337        61.0  female  29.070000        0    yes  northwest  29141.360300
# 1338        39.0    male  30.675161        0    yes  southeast  13261.018027
# 582         39.0    male  45.430000        2     no  southeast   6356.270700
#
# [1338 rows x 7 columns]

# %%
df[df['smoker']=="yes"]
# Out:
#              age     sex        bmi children smoker     region       charges
# patient_id
# 1           19.0  female  27.900000        0    yes  southwest  16884.924000
# 12          62.0  female  26.290000        0    yes  southeast  27808.725100
# 15          27.0    male  42.130000        0    yes  southeast  39611.757700
# 20          30.0    male  35.300000        0    yes  southwest  36837.467000
# 24          34.0  female  31.920000        1    yes  northeast  37701.876800
# ...          ...     ...        ...      ...    ...        ...           ...
# 1314        30.0  female  23.655000        3    yes  northwest  18765.875450
# 1321        62.0    male  26.695000        0    yes  northeast  28101.333050
# 1323        42.0  female  40.370000        2    yes  southeast  43896.376300
# 1337        61.0  female  29.070000        0    yes  northwest  29141.360300
# 1338        39.0    male  30.675161        0    yes  southeast  13261.018027
#
# [275 rows x 7 columns]

# %%
df.query(" smoker=='yes' and region=='northwest'")
# Out:
#              age     sex     bmi children smoker     region       charges
# patient_id
# 56          58.0    male  36.955        2    yes  northwest  47496.494450
# 65          20.0  female  22.420        0    yes  northwest  14711.743800
# 86          45.0    male  22.895        2    yes  northwest  21098.554050
# 87          57.0  female  31.160        0    yes  northwest  43578.939400
# 106         20.0    male  28.025        1    yes  northwest  17560.379750
# 129         32.0  female  17.765        2    yes  northwest  32734.186300
# 145         30.0    male  28.690        3    yes  northwest  20745.989100
# 147         46.0    male  30.495        3    yes  northwest  40720.551050
# 161         42.0  female  26.600        0    yes  northwest  21348.706000
# 239         19.0    male  29.070        0    yes  northwest  17352.680300
# 257         56.0    male  33.630        0    yes  northwest  43921.183700
# 260         19.0    male  31.920        0    yes  northwest  33750.291800
# 264         19.0    male  36.955        0    yes  northwest  36219.405450
# 299         31.0    male  34.390        3    yes  northwest  38746.355100
# 328         45.0    male  36.480        2    yes  northwest  42760.502200
# 332         52.0    male  27.360        0    yes  northwest  24393.622400
# 376         23.0  female  28.310        0    yes  northwest  18033.967900
# 420         63.0  female  26.980        0    yes  northwest  28950.469200
# 445         56.0    male  26.695        1    yes  northwest  26109.329050
# 476         61.0    male  28.310        1    yes  northwest  28868.663900
# 546         49.0    male  25.840        2    yes  northwest  23807.240600
# 559         35.0  female  34.105        3    yes  northwest  39983.425950
# 570         48.0    male  40.565        2    yes  northwest  45702.022350
# 587         34.0  female  30.210        1    yes  northwest  43943.876100
# 604         19.0  female  28.310        0    yes  northwest  17468.983900
# 607         59.0  female  23.655        0    yes  northwest  25678.778450
# 629         44.0  female  38.950        0    yes  northwest  42983.458500
# 641         42.0    male  28.310        3    yes  northwest  32787.458590
# 667         40.0  female  32.775        2    yes  northwest  40003.332250
# 677         60.0    male  31.350        3    yes  northwest  46130.526500
# 773         19.0  female  28.880        0    yes  northwest  17748.506200
# 795         27.0    male  28.500        0    yes  northwest  18310.742000
# 819         33.0  female  35.530        0    yes  northwest  55135.402090
# 857         25.0    male  24.130        0    yes  northwest  15817.985700
# 890         64.0  female  26.885        0    yes  northwest  29330.983150
# 916         43.0  female  26.885        0    yes  northwest  21774.322150
# 954         34.0    male  27.835        1    yes  northwest  20009.633650
# 966         51.0    male  24.795        2    yes  northwest  23967.383050
# 994         27.0  female  20.045        3    yes  northwest  16420.494550
# 1000        30.0    male  22.990        2    yes  northwest  17361.766100
# 1007        47.0    male  28.215        3    yes  northwest  24915.220850
# 1026        19.0    male  26.030        1    yes  northwest  16450.894700
# 1030        46.0  female  23.655        1    yes  northwest  21677.283450
# 1037        45.0  female  30.495        1    yes  northwest  39725.518050
# 1040        35.0  female  28.025        0    yes  northwest  20234.854750
# 1045        43.0  female  24.700        2    yes  northwest  21880.820000
# 1093        22.0  female  30.400        0    yes  northwest  33907.548000
# 1122        53.0  female  36.860        3    yes  northwest  46661.442400
# 1139        19.0  female  32.490        0    yes  northwest  36898.733080
# 1176        52.0  female  24.130        1    yes  northwest  23887.662700
# 1186        20.0    male  35.625        3    yes  northwest  13261.018027
# 1196        19.0  female  30.020        0    yes  northwest  33307.550800
# 1230        52.0    male  34.485        3    yes  northwest  60021.398970
# 1281        47.0  female  27.645        2    yes  northwest  24535.698550
# 1301        62.0    male  30.875        3    yes  northwest  46718.163250
# 1307        32.0    male  28.120        4    yes  northwest  21472.478800
# 1314        30.0  female  23.655        3    yes  northwest  18765.875450
# 1337        61.0  female  29.070        0    yes  northwest  29141.360300

# %% [markdown]
# displaying the total no.of smokers present in the northwest region

# %% [markdown]
# # **Visualization**

# %% [markdown]
# ## Scatter plot

# %%
f = plt.figure(figsize=(14,6))
ax = f.add_subplot(122)
sns.scatterplot(x='bmi',y='charges',data=df,palette='viridis',hue='smoker')
ax.set_title('Scatter plot of Charges vs bmi')
plt.savefig('sc.png');

# %% [markdown]
# We can infer that as the charges grows the smokers rate also grows

# %% [markdown]
# ## Strip plot

# %%
plt.figure(figsize=(17,7))
sns.stripplot(x= "region", y = "charges", hue="sex", size=10, data = df,marker= 'd',palette='RdPu')
plt.show()

# %%
plt.figure(figsize=(17,7))
sns.stripplot(x= "region", y = "charges", hue="sex", size=10, data = df,dodge=True,marker= 'd',palette='RdPu')
plt.show()

# %% [markdown]
# we can infer that their are  more no.of males in southeast and northwest than compared to other regions more no.of people having less charges

# %% [markdown]
# ## Swarm plot

# %%
plt.figure(figsize=(27,17))
sns.swarmplot(x= "region", y = "charges", hue="smoker", size=10, data = df,marker= '*')
plt.show()

# %% [markdown]
# we can infer that compared to other regions in southwest  having less smokers even the charges goes up

# %% [markdown]
# ## Heat map

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, fmt='.1g', cmap="RdPu", cbar=True);

# %% [markdown]
# we can infer that bmi and age are lowly correlated

# %% [markdown]
# ##  Bar plot

# %%
fig = plt.figure(figsize = (10, 5))
# creating the bar plot
plt.bar(df.sex, df.bmi, color ='lime',width = 0.4)
plt.xlabel("gender")
plt.ylabel("bmi")
plt.title("Students enrolled in different courses")
plt.show()

# %% [markdown]
# we can infer that  more no.of mens are obese compared to females

# %% [markdown]
# ## Violin plot and Box plot

# %%
#Creating a violinplot for each category
plt.figure(figsize=(22,14))
sns.violinplot(x='children', y='charges', data=df, hue='sex', palette='RdPu')
sns.boxplot(x='children', y='charges', data=df, hue='sex', palette='YlGnBu')
plt.title('Charges according to number of children', size='23')
plt.ylabel('Charges',size=18)
plt.xlabel('Number of children',size=18)
plt.show()

# %% [markdown]
# people both the male and females  with 4 childs are having same median  and compared to males females having more outliers

# %% [markdown]
# ## Hist plot

# %%
df.hist(bins=40 , figsize=(20,20)) #Pandas Hist function
plt.show()

# %% [markdown]
# ## Pie chart

# %%
plt.style.use("seaborn")
fig, ax = plt.subplots(figsize=(5,5))
plt.pie(x=df["sex"].value_counts(), 
        colors=["skyblue","pink"], 
        labels=["Male","Female"], 
        shadow = True, 
        autopct="%1.2f%%", 
        explode = (0, 0.1)
        )
plt.show()

# %% [markdown]
# we can infer that male are more in number than female

# %% [markdown]
# ##Box plot

# %%
plt.figure(figsize=(28,16))
sns.boxplot(x=df.smoker, y=df.charges,palette='RdPu')
sns.swarmplot(x=df.smoker, y=df.charges)

# %% [markdown]
# smokers skewed to the left and people who dont smoke skewed to the right and their are few outliers in no part

# %% [markdown]
# ## Count plot

# %%
sns.countplot(x='region',data=df)

# %% [markdown]
# we can infer that compared to other regions more no.of people live in southeast

# %%
#Countplot to compare the number of smokers and non-smokers
plt.figure(figsize=(12,4))
sns.countplot(x='smoker', data=df, hue='sex', palette='YlOrBr') 
plt.title('Number of smokers and non-smokers', size='23')
plt.ylabel('Count',size=18)
plt.xlabel('Smoker',size=18)
plt.show()

# %% [markdown]
# we can infer that male smoke more than female

# %%
plt.style.use("seaborn")
fig, ax = plt.subplots(figsize=(16,16))
sns.countplot(df["children"], palette="hls");
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# we can infer that their are more people with no children

# %% [markdown]
# ## Distribution plot

# %%
x1 = sns.FacetGrid(df, row='sex', height=4, aspect=3)
x1 = x1.map(sns.distplot, 'charges', color='cornflowerblue')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(data=df,x="bmi",kind='kde',bw_adjust=6)
sns.displot(data=df,x="charges",kind='kde',bw_adjust=6)

# %% [markdown]
# we can infer that bmi is normally distributed and charges are slightly skewed to the left

# %%
sns.displot(df.age, kde=True) # Histogram with a kernel density estimate (Density Curve)
plt.show()

# %% [markdown]
# # Encoding

# %%
df.dtypes
# Out:
# age         float64
# sex          object
# bmi         float64
# children     object
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
data=df

# %%
var_df = df.select_dtypes(include=['object']).copy()
var_df.head()
# Out:
#                sex children smoker     region
# patient_id
# 1           female        0    yes  southwest
# 2             male        1     no  southeast
# 3             male        3     no  southeast
# 4             male        0     no  northwest
# 5             male        0     no  northwest

# %%
var_df[var_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [sex, children, smoker, region]
# Index: []

# %% [markdown]
# as we took care of the null values we can proceed with encoding with the catagorical data in order to analyse the data effectly
# catagorical variables are:

# %%
var_df.columns
# Out:
# Index(['sex', 'children', 'smoker', 'region'], dtype='object')

# %% [markdown]
# no.of children will follow certain order so we will  label encode "children" column and proceed with one hot encoding for other columns

# %%
var_df['children'].value_counts()
# Out:
# 0    576
# 1    324
# 2    239
# 3    156
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
var_df["children"] = le.fit_transform(var_df['children'])
var_df
# Out:
#                sex  children smoker     region
# patient_id
# 1           female         0    yes  southwest
# 2             male         1     no  southeast
# 3             male         3     no  southeast
# 4             male         0     no  northwest
# 5             male         0     no  northwest
# ...            ...       ...    ...        ...
# 1335        female         0     no  southeast
# 1336        female         0     no  southwest
# 1337        female         0    yes  northwest
# 1338          male         0    yes  southeast
# 582           male         2     no  southeast
#
# [1338 rows x 4 columns]

# %%
var_df['children'].value_counts()
# Out:
# 0    576
# 1    324
# 2    239
# 3    156
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
var_df2=pd.get_dummies(var_df, columns=['sex','region']).head()
var_df2.head()
var_df2['children'].value_counts()
# Out:
# 0    3
# 3    1
# 1    1
# Name: children, dtype: int64

# %%
df['children']=var_df['children']
df['children'].value_counts()
# Out:
# 0    576
# 1    324
# 2    239
# 3    156
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df=pd.get_dummies(df, columns=['sex','region','smoker'])
df.head()
# Out:
#              age     bmi  children  ...  region_southwest  smoker_no  smoker_yes
# patient_id                          ...
# 1           19.0  27.900         0  ...                 1          0           1
# 2           18.0  33.770         1  ...                 0          1           0
# 3           28.0  33.000         3  ...                 0          1           0
# 4           33.0  22.705         0  ...                 0          1           0
# 5           32.0  28.880         0  ...                 0          1           0
#
# [5 rows x 12 columns]

# %%
df['children'].value_counts()
# Out:
# 0    576
# 1    324
# 2    239
# 3    156
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df.isnull().sum()
# Out:
# age                 0
# bmi                 0
# children            0
# charges             0
# sex_female          0
# sex_male            0
# region_northeast    0
# region_northwest    0
# region_southeast    0
# region_southwest    0
# smoker_no           0
# smoker_yes          0
# dtype: int64

# %%
df.dtypes
# Out:
# age                 float64
# bmi                 float64
# children              int64
# charges             float64
# sex_female            uint8
# sex_male              uint8
# region_northeast      uint8
# region_northwest      uint8
# region_southeast      uint8
# region_southwest      uint8
# smoker_no             uint8
# smoker_yes            uint8
# dtype: object

# %% [markdown]
# # removing outliers

# %%
my_list = df['bmi']

# %%
def get_lower_upper_bound(my_data):
    # Get first and third quartile
    q1 = np.percentile(my_data, 25)
    q3 = np.percentile(my_data, 75)
    
    # Calculate Interquartile range
    iqr = q3 - q1
    
    # Compute lower and upper bound
    lower_bound = q1 - (iqr * 1.5)
    upper_bound = q3 + (iqr * 1.5)
    
    return lower_bound, upper_bound

# %%
def get_outliers_iqr(my_data):
    lower_bound, upper_bound = get_lower_upper_bound(my_data)
    # Filter data less than lower bound and more than upper bound
    return my_data[np.where((my_data > upper_bound) |
                            (my_data < lower_bound))]

# %%
Q1 = np.percentile(my_list,25)
Q2 = np.percentile(my_list,50)
Q3 = np.percentile(my_list,75)
print("Q1: ",Q1)
print("Q2: ",Q2)
print("Median:",np.median(my_list))
print("Q3: ",Q3)
# Out:
# Q1:  26.315
# Q2:  30.4
# Median: 30.4
# Q3:  34.69375

# %%
IQR=Q3-Q1
print("Inter Quartile Range: ",IQR)
# Out:
# Inter Quartile Range:  8.37875

# %%
# Convert the list to dataframe and add column name


# Plot using seaborm
sns.boxplot(data=pd.DataFrame(df['bmi']))

# Add ylabel
plt.ylabel('Data points')
# Out:
# Text(0, 0.5, 'Data points')

# %%
outlier=get_outliers_iqr(my_list.values)

# %%
p=[]
for i in df.index.values:
  if df.loc[i,'bmi'] in outlier:
    p.append(i)
p
# Out:
# [117, 287, 402, 544, 847, 860, 1047, 1088, 1317]

# %%
for i  in p:
  df.drop(i,inplace=True,axis=0)
df
# Out:
#              age        bmi  children  ...  region_southwest  smoker_no  smoker_yes
# patient_id                             ...
# 1           19.0  27.900000         0  ...                 1          0           1
# 2           18.0  33.770000         1  ...                 0          1           0
# 3           28.0  33.000000         3  ...                 0          1           0
# 4           33.0  22.705000         0  ...                 0          1           0
# 5           32.0  28.880000         0  ...                 0          1           0
# ...          ...        ...       ...  ...               ...        ...         ...
# 1335        18.0  36.850000         0  ...                 0          1           0
# 1336        21.0  25.800000         0  ...                 1          1           0
# 1337        61.0  29.070000         0  ...                 0          0           1
# 1338        39.0  30.675161         0  ...                 0          0           1
# 582         39.0  45.430000         2  ...                 0          1           0
#
# [1329 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

val_df=df
val_df.drop('charges',axis=1)
data_standrd=scaler.fit_transform(val_df)
data_standrd
# Out:
# array([[-1.44077267, -0.44852999, -0.90530412, ...,  1.7612075 ,
#         -1.97130145,  1.97130145],
#        [-1.51208954,  0.54530947, -0.07668899, ..., -0.56779227,
#          0.50727909, -0.50727909],
#        [-0.79892076,  0.41494211,  1.58054128, ..., -0.56779227,
#          0.50727909, -0.50727909],
#        ...,
#        [ 1.55453623, -0.25043933, -0.90530412, ..., -0.56779227,
#         -1.97130145,  1.97130145],
#        [-0.01443509,  0.02132769, -0.90530412, ..., -0.56779227,
#         -1.97130145,  1.97130145],
#        [-0.01443509,  2.51944372,  0.75192615, ..., -0.56779227,
#          0.50727909, -0.50727909]])

# %% [markdown]
# #Heat map

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, fmt='.1g', cmap="viridis", cbar=True);

# %% [markdown]
# smokers and charges are linearly related as charges smokers  increases no.of smokers also increases

# %% [markdown]
# #Exploratory Data Analysis

# %%
edf=df
edf
# Out:
#              age        bmi  children  ...  region_southwest  smoker_no  smoker_yes
# patient_id                             ...
# 1           19.0  27.900000         0  ...                 1          0           1
# 2           18.0  33.770000         1  ...                 0          1           0
# 3           28.0  33.000000         3  ...                 0          1           0
# 4           33.0  22.705000         0  ...                 0          1           0
# 5           32.0  28.880000         0  ...                 0          1           0
# ...          ...        ...       ...  ...               ...        ...         ...
# 1335        18.0  36.850000         0  ...                 0          1           0
# 1336        21.0  25.800000         0  ...                 1          1           0
# 1337        61.0  29.070000         0  ...                 0          0           1
# 1338        39.0  30.675161         0  ...                 0          0           1
# 582         39.0  45.430000         2  ...                 0          1           0
#
# [1329 rows x 12 columns]

# %% [markdown]
# Crosstab

# %% [markdown]
# North-East

# %%
pd.crosstab(edf.sex_male, edf.region_northeast,values=edf.smoker_yes,aggfunc=np.average)
# Out:
# region_northeast         0         1
# sex_male
# 0                 0.168337  0.181250
# 1                 0.238659  0.233129

# %% [markdown]
# In North-east Region :
#
# 23% of males are smokers
#
# 18% of females are smokers

# %%
pd.crosstab(edf.sex_male, edf.region_northeast,values=edf.charges,aggfunc=np.average)
# Out:
# region_northeast             0             1
# sex_male
# 0                 12275.975047  12975.204888
# 1                 13977.635064  13854.005374

# %% [markdown]
# Average charges of male in north-east Region = 13854
#
# Average charges of female in North-east Region = 12975

# %% [markdown]
# North-west

# %%
pd.crosstab(edf.sex_male, edf.region_northwest,values=edf.smoker_yes,aggfunc=np.average)
# Out:
# region_northwest         0         1
# sex_male
# 0                 0.169355  0.177914
# 1                 0.254902  0.181250

# %% [markdown]
# In North-west Region :
#
# 18% of males are smokers
#
# 17% of females are smokers

# %%
pd.crosstab(edf.sex_male, edf.region_northwest,values=edf.charges,aggfunc=np.average)
# Out:
# region_northwest             0             1
# sex_male
# 0                 12438.108424  12468.972713
# 1                 14473.910766  12269.808517

# %% [markdown]
# Average charges of male in north-west Region = 12269.8
#
# Average charges of female in North-west Region = 12468.9

# %% [markdown]
# South-East

# %%
pd.crosstab(edf.sex_male, edf.region_southeast,values=edf.smoker_yes,aggfunc=np.average)
# Out:
# region_southeast         0         1
# sex_male
# 0                 0.161157  0.200000
# 1                 0.213992  0.298913

# %% [markdown]
# In South-east Region :
#
# 29% of males are smokers
#
# 20% of females are smokers

# %%
pd.crosstab(edf.sex_male, edf.region_southeast,values=edf.charges,aggfunc=np.average)
# Out:
# region_southeast             0             1
# sex_male
# 0                 12166.976132  13216.730756
# 1                 13184.510826  15962.997782

# %% [markdown]
# Average charges of male in south-east Region = 15962.9
#
# Average charges of female in south-east Region = 13216.7

# %% [markdown]
# South-west

# %%
pd.crosstab(edf.sex_male, edf.region_southwest,values=edf.smoker_yes,aggfunc=np.average)
# Out:
# region_southwest         0         1
# sex_male
# 0                 0.186747  0.124224
# 1                 0.240631  0.226994

# %% [markdown]
# In South-west Region :
#
# 22% of males are smokers
#
# 12% of females are smokers

# %%
pd.crosstab(edf.sex_male, edf.region_southwest,values=edf.charges,aggfunc=np.average)
# Out:
# region_southwest             0             1
# sex_male
# 0                 12894.383969  11058.019340
# 1                 14119.455287  13412.883576

# %% [markdown]
# Average charges of male in south-west Region = 13412.8
#
# Average charges of female in south-west Region = 11058

# %%
pd.crosstab(edf.sex_male,edf.smoker_yes,values=edf.charges,aggfunc=np.average)
# Out:
# smoker_yes            0             1
# sex_male
# 0           8761.069043  30249.563122
# 1           8114.735047  32693.297133

# %% [markdown]
# So, By the Above Cross tab we can say average charge on a male if he is a smoker:32693.29
#
# Female if she is a smoker:30249.563
#
# Male if he is not a smoker : 8114.73
#
# Female if she is not a smoker : 8761

# %%
pd.crosstab(edf.sex_male,edf.smoker_yes,values=edf.bmi,aggfunc=np.average)
# Out:
# smoker_yes          0          1
# sex_male
# 0           30.507418  29.291504
# 1           30.617662  31.366416

# %% [markdown]
# As we can see both male and female either smoker or non-smoker on an average they have Almost same BMI
#
# But we can observe that smoker female are having less BMI Compared to non-smoker female BMI
#
# And Smoker male is having more BMI Compared to non-smoker male BMI

# %%
pd.crosstab(edf.sex_male,edf.smoker_yes)
# Out:
# smoker_yes    0    1
# sex_male
# 0           546  113
# 1           511  159

# %%
pd.crosstab(edf.sex_male, edf.age,values=edf.charges,aggfunc=np.average,margins=True)
# Out:
# age              18.0          19.0  ...          64.0           All
# sex_male                             ...
# 0         6522.257919   9611.799484  ...  23493.178700  12445.742535
# 1         7787.172496  10118.496726  ...  23057.882975  13947.557990
# All       7173.316892   9868.929428  ...  23275.530837  13202.865451
#
# [3 rows x 48 columns]

# %% [markdown]
# Above is the Average charges of Different age groups across all the regions.
#
# Age 60,61,64 has an average charge above 20000

# %% [markdown]
# Conclusion:
#
# Out of all regions South-west females smoke less
#
# So they have low charges
#
# And more number South-east males smoke
#
# So, they have high charges

# %% [markdown]
# Sorting Values

# %%
sv=edf.sort_values(['charges'],ascending=False)
sv[['charges','age','smoker_yes','sex_male']].head(50)
# Out:
#                 charges   age  smoker_yes  sex_male
# patient_id
# 1300        62592.87309  45.0           1         1
# 1230        60021.39897  52.0           1         1
# 578         58571.07448  31.0           1         0
# 819         55135.40209  33.0           1         0
# 1146        52590.82939  60.0           1         1
# 35          51194.55914  28.0           1         1
# 1241        49577.66240  64.0           1         1
# 1062        48970.24760  59.0           1         1
# 489         48885.13561  44.0           1         0
# 176         48824.45000  63.0           1         0
# 531         48675.51770  57.0           1         1
# 901         48673.55880  60.0           1         1
# 282         48549.17835  54.0           1         1
# 331         48517.56315  61.0           1         0
# 40          48173.36100  60.0           1         1
# 329         47928.03000  64.0           1         0
# 289         47896.79135  59.0           1         0
# 56          47496.49445  58.0           1         1
# 951         47462.89400  51.0           1         1
# 1284        47403.88000  61.0           1         1
# 252         47305.30500  63.0           1         0
# 95          47291.05500  64.0           1         0
# 1240        47269.85400  52.0           1         1
# 110         47055.53210  63.0           1         1
# 421         46889.26120  64.0           1         1
# 1301        46718.16325  62.0           1         1
# 1122        46661.44240  53.0           1         0
# 422         46599.10840  61.0           1         1
# 883         46255.11250  51.0           1         0
# 674         46200.98510  44.0           1         0
# 266         46151.12450  46.0           1         1
# 677         46130.52650  60.0           1         1
# 550         45863.20500  43.0           1         0
# 668         45710.20785  62.0           1         1
# 570         45702.02235  48.0           1         1
# 845         45008.95550  60.0           1         0
# 1096        44641.19740  51.0           1         0
# 739         44585.45587  29.0           1         1
# 1031        44423.80300  55.0           1         0
# 706         44400.40640  51.0           1         0
# 253         44260.74990  54.0           1         1
# 893         44202.65360  47.0           1         1
# 587         43943.87610  34.0           1         0
# 257         43921.18370  56.0           1         1
# 1323        43896.37630  42.0           1         0
# 826         43813.86610  56.0           1         1
# 186         43753.33705  36.0           1         1
# 87          43578.93940  57.0           1         0
# 742         43254.41795  53.0           1         1
# 629         42983.45850  44.0           1         0

# %%
sv[['charges','age','smoker_yes','sex_male']].tail(60)
# Out:
#                charges   age  smoker_yes  sex_male
# patient_id
# 1129        1728.89700  19.0           0         0
# 233         1727.78500  19.0           0         0
# 710         1727.54000  18.0           0         1
# 2           1725.55230  18.0           0         1
# 1283        1720.35370  18.0           0         1
# 271         1719.43630  18.0           0         1
# 648         1712.22700  18.0           0         1
# 1023        1711.02680  18.0           0         1
# 1296        1708.92575  18.0           0         1
# 530         1708.00140  18.0           0         1
# 122         1705.62450  18.0           0         1
# 1041        1704.70015  18.0           0         1
# 296         1704.56810  18.0           0         1
# 1212        1702.45530  18.0           0         1
# 173         1694.79640  18.0           0         1
# 888         1682.59700  22.0           0         1
# 1097        1674.63230  22.0           0         1
# 577         1664.99960  22.0           0         1
# 560         1646.42970  19.0           0         1
# 196         1639.56310  19.0           0         1
# 350         1635.73365  19.0           0         1
# 898         1634.57340  18.0           0         0
# 1248        1633.96180  18.0           0         0
# 600         1633.04440  18.0           0         0
# 134         1632.56445  19.0           0         1
# 465         1632.03625  19.0           0         1
# 182         1631.82120  18.0           0         0
# 400         1631.66830  18.0           0         0
# 1335        1629.83350  18.0           0         0
# 943         1628.47090  19.0           0         1
# 747         1627.28245  19.0           0         1
# 36          1625.43375  19.0           0         1
# 483         1622.18850  18.0           0         0
# 822         1621.88270  18.0           0         0
# 411         1621.34020  19.0           0         1
# 237         1615.76670  18.0           0         0
# 360         1607.51010  18.0           0         0
# 479         1534.30450  21.0           0         1
# 78          1532.46970  21.0           0         1
# 840         1526.31200  21.0           0         1
# 1292        1515.34490  21.0           0         1
# 375         1391.52870  20.0           0         1
# 723         1263.24900  19.0           0         1
# 386         1261.85900  19.0           0         1
# 137         1261.44200  19.0           0         1
# 514         1256.29900  19.0           0         1
# 488         1253.93600  19.0           0         1
# 791         1252.40700  19.0           0         1
# 584         1242.81600  19.0           0         1
# 681         1242.26000  19.0           0         1
# 1251        1241.56500  19.0           0         1
# 443         1149.39590  18.0           0         1
# 781         1146.79660  18.0           0         1
# 866         1141.44510  18.0           0         1
# 195         1137.46970  18.0           0         1
# 23          1137.01100  18.0           0         1
# 663         1136.39940  18.0           0         1
# 1244        1135.94070  18.0           0         1
# 808         1131.50660  18.0           0         1
# 940         1121.87390  18.0           0         1

# %% [markdown]
# By the above sorted values we can say that smokers are getting high charges compared to non-smokers.

# %%
sv1=edf.sort_values(['sex_male','charges'],ascending=False)
sv1[['sex_male', 'charges','age']].head(50)
# Out:
#             sex_male      charges   age
# patient_id
# 1300               1  62592.87309  45.0
# 1230               1  60021.39897  52.0
# 1146               1  52590.82939  60.0
# 35                 1  51194.55914  28.0
# 1241               1  49577.66240  64.0
# 1062               1  48970.24760  59.0
# 531                1  48675.51770  57.0
# 901                1  48673.55880  60.0
# 282                1  48549.17835  54.0
# 40                 1  48173.36100  60.0
# 56                 1  47496.49445  58.0
# 951                1  47462.89400  51.0
# 1284               1  47403.88000  61.0
# 1240               1  47269.85400  52.0
# 110                1  47055.53210  63.0
# 421                1  46889.26120  64.0
# 1301               1  46718.16325  62.0
# 422                1  46599.10840  61.0
# 266                1  46151.12450  46.0
# 677                1  46130.52650  60.0
# 668                1  45710.20785  62.0
# 570                1  45702.02235  48.0
# 739                1  44585.45587  29.0
# 253                1  44260.74990  54.0
# 893                1  44202.65360  47.0
# 257                1  43921.18370  56.0
# 826                1  43813.86610  56.0
# 186                1  43753.33705  36.0
# 742                1  43254.41795  53.0
# 272                1  42856.83800  50.0
# 328                1  42760.50220  45.0
# 665                1  42560.43040  43.0
# 382                1  42303.69215  55.0
# 1022               1  42211.13820  47.0
# 313                1  42124.51530  43.0
# 293                1  42112.23560  25.0
# 956                1  41999.52000  54.0
# 1111               1  41949.24410  38.0
# 339                1  41919.09700  50.0
# 1090               1  41676.08110  47.0
# 255                1  41097.16175  50.0
# 958                1  41034.22140  43.0
# 147                1  40720.55105  46.0
# 697                1  40273.64550  41.0
# 621                1  40182.24600  37.0
# 682                1  40103.89000  39.0
# 1070               1  39871.70430  37.0
# 39                 1  39774.27630  35.0
# 1049               1  39727.61400  49.0
# 1156               1  39722.74620  19.0

# %% [markdown]
# By the above sorted values we can say that most of the males who are above 45 age are getting high charges.

# %%
sv2=edf.sort_values(['smoker_yes','sex_male','charges'],ascending=False)
sv2[['charges','sex_male','age', 'smoker_yes']].head(60)
# Out:
#                 charges  sex_male   age  smoker_yes
# patient_id
# 1300        62592.87309         1  45.0           1
# 1230        60021.39897         1  52.0           1
# 1146        52590.82939         1  60.0           1
# 35          51194.55914         1  28.0           1
# 1241        49577.66240         1  64.0           1
# 1062        48970.24760         1  59.0           1
# 531         48675.51770         1  57.0           1
# 901         48673.55880         1  60.0           1
# 282         48549.17835         1  54.0           1
# 40          48173.36100         1  60.0           1
# 56          47496.49445         1  58.0           1
# 951         47462.89400         1  51.0           1
# 1284        47403.88000         1  61.0           1
# 1240        47269.85400         1  52.0           1
# 110         47055.53210         1  63.0           1
# 421         46889.26120         1  64.0           1
# 1301        46718.16325         1  62.0           1
# 422         46599.10840         1  61.0           1
# 266         46151.12450         1  46.0           1
# 677         46130.52650         1  60.0           1
# 668         45710.20785         1  62.0           1
# 570         45702.02235         1  48.0           1
# 739         44585.45587         1  29.0           1
# 253         44260.74990         1  54.0           1
# 893         44202.65360         1  47.0           1
# 257         43921.18370         1  56.0           1
# 826         43813.86610         1  56.0           1
# 186         43753.33705         1  36.0           1
# 742         43254.41795         1  53.0           1
# 272         42856.83800         1  50.0           1
# 328         42760.50220         1  45.0           1
# 665         42560.43040         1  43.0           1
# 382         42303.69215         1  55.0           1
# 1022        42211.13820         1  47.0           1
# 313         42124.51530         1  43.0           1
# 293         42112.23560         1  25.0           1
# 956         41999.52000         1  54.0           1
# 1111        41949.24410         1  38.0           1
# 339         41919.09700         1  50.0           1
# 1090        41676.08110         1  47.0           1
# 255         41097.16175         1  50.0           1
# 958         41034.22140         1  43.0           1
# 147         40720.55105         1  46.0           1
# 697         40273.64550         1  41.0           1
# 621         40182.24600         1  37.0           1
# 682         40103.89000         1  39.0           1
# 1070        39871.70430         1  37.0           1
# 39          39774.27630         1  35.0           1
# 1049        39727.61400         1  49.0           1
# 1156        39722.74620         1  19.0           1
# 15          39611.75770         1  27.0           1
# 828         39597.40720         1  41.0           1
# 124         39556.49450         1  44.0           1
# 609         39241.44200         1  30.0           1
# 423         39125.33225         1  40.0           1
# 947         39047.28500         1  37.0           1
# 953         38998.54600         1  44.0           1
# 299         38746.35510         1  31.0           1
# 30          38711.00000         1  31.0           1
# 50          38709.17600         1  36.0           1

# %% [markdown]
# most of the males who are smokers are getting high charges irrespective of their age

# %%
sv3=edf.sort_values(['smoker_no','sex_male','charges'],ascending=False)
sv3[['smoker_no','sex_male', 'age','charges']].head(60)
# Out:
#             smoker_no  sex_male   age      charges
# patient_id
# 936                 1         1  44.0  32108.66282
# 388                 1         1  50.0  30284.64294
# 116                 1         1  60.0  30259.99556
# 63                  1         1  64.0  30166.61817
# 1258                1         1  55.0  30063.58055
# 959                 1         1  48.0  28468.91901
# 770                 1         1  61.0  27941.28758
# 517                 1         1  20.0  27724.28875
# 141                 1         1  34.0  27375.90478
# 540                 1         1  53.0  27346.04207
# 380                 1         1  62.0  27000.98473
# 964                 1         1  52.0  26467.09737
# 290                 1         1  52.0  25992.82104
# 980                 1         1  54.0  25517.11363
# 925                 1         1  50.0  25333.33284
# 356                 1         1  46.0  24603.04837
# 246                 1         1  54.0  24476.47851
# 1211                1         1  39.0  23563.01618
# 1008                1         1  25.0  23241.47453
# 431                 1         1  19.0  23082.95533
# 1039                1         1  19.0  22493.65964
# 4                   1         1  33.0  21984.47061
# 456                 1         1  59.0  21797.00040
# 1027                1         1  23.0  21595.38229
# 1003                1         1  48.0  21232.18226
# 383                 1         1  55.0  20781.48892
# 1132                1         1  57.0  20709.02034
# 46                  1         1  55.0  20630.28351
# 1104                1         1  37.0  20420.60465
# 292                 1         1  29.0  20277.80751
# 1134                1         1  28.0  19673.33573
# 1318                1         1  35.0  19496.71917
# 306                 1         1  29.0  19442.35350
# 534                 1         1  37.0  19214.70553
# 1162                1         1  30.0  18963.17192
# 644                 1         1  43.0  18806.14547
# 144                 1         1  29.0  18157.87600
# 754                 1         1  24.0  17128.42608
# 398                 1         1  21.0  16586.49771
# 481                 1         1  63.0  15555.18875
# 908                 1         1  63.0  15170.06900
# 1079                1         1  63.0  15161.53440
# 399                 1         1  64.0  14988.43200
# 1272                1         1  43.0  14478.33015
# 419                 1         1  64.0  14418.28040
# 635                 1         1  64.0  14410.93210
# 1051                1         1  64.0  14394.55790
# 1128                1         1  34.0  14358.36437
# 1068                1         1  63.0  14349.85440
# 752                 1         1  64.0  14210.53595
# 851                 1         1  61.0  14119.62000
# 344                 1         1  63.0  13981.85035
# 1071                1         1  63.0  13974.45555
# 338                 1         1  62.0  13937.66650
# 436                 1         1  60.0  13919.82290
# 535                 1         1  64.0  13831.11520
# 336                 1         1  64.0  13822.80300
# 34                  1         1  63.0  13770.09790
# 894                 1         1  62.0  13555.00490
# 171                 1         1  63.0  13405.39030

# %% [markdown]
# Charges are low for non-smoker males irrespective of their age compared to the males who smoke.

# %%
sv5=edf.sort_values(['smoker_yes','sex_female','charges'],ascending=False)
sv5[['smoker_yes','sex_female', 'charges']]
# Out:
#             smoker_yes  sex_female      charges
# patient_id
# 578                  1           1  58571.07448
# 819                  1           1  55135.40209
# 489                  1           1  48885.13561
# 176                  1           1  48824.45000
# 331                  1           1  48517.56315
# ...                ...         ...          ...
# 23                   0           0   1137.01100
# 663                  0           0   1136.39940
# 1244                 0           0   1135.94070
# 808                  0           0   1131.50660
# 940                  0           0   1121.87390
#
# [1329 rows x 3 columns]

# %% [markdown]
# Females who smoke are getting high charges

# %%
sv6=edf.sort_values(['smoker_no','sex_female','charges'],ascending=False)
sv6[['smoker_no','sex_female', 'charges']]
# Out:
#             smoker_no  sex_female       charges
# patient_id
# 1206                1           1  36910.608030
# 1012                1           1  36580.282160
# 243                 1           1  35160.134570
# 599                 1           1  33471.971890
# 574                 1           1  31620.001060
# ...               ...         ...           ...
# 158                 0           0  15518.180250
# 1033                0           0  13747.872350
# 1186                0           0  13261.018027
# 1338                0           0  13261.018027
# 251                 0           0  12829.455100
#
# [1329 rows x 3 columns]

# %% [markdown]
# Females who do not smoke are getting low charges compared to smoking women

# %% [markdown]
# Grouping

# %% [markdown]
# Region-Northeast

# %% [markdown]
# Total Population:323
#
# smokers:67
#
# non-smokers:256

# %%
G=edf.groupby(['region_northeast'])

# %%
G1=G.get_group(1)

# %% [markdown]
# Taking only North-east people to a separate dataframe(G1).

# %%
svG1=G1.sort_values(['charges'],ascending=False)
svG1[['charges','age','sex_male','smoker_yes']].head(60)
# Out:
#                 charges   age  sex_male  smoker_yes
# patient_id
# 578         58571.07448  31.0         0           1
# 282         48549.17835  54.0         1           1
# 331         48517.56315  61.0         0           1
# 289         47896.79135  59.0         0           1
# 883         46255.11250  51.0         0           1
# 668         45710.20785  62.0         1           1
# 1096        44641.19740  51.0         0           1
# 186         43753.33705  36.0         1           1
# 742         43254.41795  53.0         1           1
# 382         42303.69215  55.0         1           1
# 852         42111.66470  46.0         0           1
# 339         41919.09700  50.0         1           1
# 255         41097.16175  50.0         1           1
# 958         41034.22140  43.0         1           1
# 1124        40904.19950  23.0         0           1
# 39          39774.27630  35.0         1           1
# 828         39597.40720  41.0         1           1
# 124         39556.49450  44.0         1           1
# 423         39125.33225  40.0         1           1
# 947         39047.28500  37.0         1           1
# 241         38511.62830  23.0         0           1
# 24          37701.87680  34.0         0           1
# 1249        37607.52770  32.0         1           1
# 850         37270.15120  37.0         0           1
# 738         36189.10170  23.0         1           1
# 477         35147.52848  24.0         1           1
# 917         35069.37452  45.0         1           1
# 623         34617.84065  18.0         1           1
# 1267        34254.05335  24.0         1           1
# 911         33732.68670  18.0         1           1
# 1042        33475.81715  20.0         1           1
# 936         32108.66282  44.0         1           0
# 574         31620.00106  62.0         0           0
# 116         30259.99556  60.0         1           0
# 93          30184.93670  59.0         1           1
# 245         29523.16560  63.0         0           1
# 696         29186.48236  53.0         0           0
# 1321        28101.33305  62.0         1           1
# 141         27375.90478  34.0         1           0
# 886         27218.43725  57.0         1           1
# 658         26392.26029  48.0         0           0
# 521         25656.57526  50.0         0           0
# 980         25517.11363  54.0         1           0
# 925         25333.33284  50.0         1           0
# 637         24915.04626  35.0         0           0
# 302         24873.38490  53.0         0           1
# 263         24869.83680  52.0         1           1
# 322         24671.66334  26.0         0           0
# 854         24106.91255  49.0         0           1
# 818         23401.30575  47.0         0           1
# 469         23288.92840  28.0         0           0
# 1008        23241.47453  25.0         1           0
# 1098        23045.56616  52.0         0           0
# 1278        22462.04375  39.0         1           1
# 99          22412.64850  56.0         1           1
# 1328        22395.74424  23.0         0           0
# 281         22331.56680  40.0         0           1
# 1188        21771.34230  43.0         0           1
# 377         21659.93010  39.0         0           1
# 103         21344.84670  18.0         0           0

# %% [markdown]
# In the North-east Region
#
# High charges are for people who smoke
#
# And there are some people who do not smoke but have high charges.

# %%
G1['smoker_yes'].value_counts()
# Out:
# 0    256
# 1     67
# Name: smoker_yes, dtype: int64

# %% [markdown]
# In North-East Region:
#
# Out of 323 people 67 smoke.

# %%
G11=G1.groupby('smoker_yes')

# %%
G111=G11.get_group(1)

# %% [markdown]
# Taking only smokers from North-east region to a separate Dataframe(G111)

# %%
G111['children'].value_counts()
# Out:
# 0    26
# 1    22
# 3    10
# 2     9
# Name: children, dtype: int64

# %% [markdown]
# In North-East Region:
#
# Out of 67 people who smoke:
#
# 26 people have no children
#
# 22 people have 1 child
#
# 10 people have 3 children
#
# 9 people  have 2 children

# %%
G111['age'].value_counts()
# Out:
# 18.0    7
# 24.0    4
# 29.0    3
# 43.0    3
# 39.0    3
# 23.0    3
# 37.0    3
# 33.0    2
# 40.0    2
# 50.0    2
# 36.0    2
# 62.0    2
# 53.0    2
# 42.0    2
# 44.0    2
# 51.0    2
# 59.0    2
# 35.0    2
# 54.0    1
# 56.0    1
# 63.0    1
# 52.0    1
# 32.0    1
# 55.0    1
# 61.0    1
# 27.0    1
# 20.0    1
# 26.0    1
# 31.0    1
# 21.0    1
# 47.0    1
# 41.0    1
# 46.0    1
# 49.0    1
# 57.0    1
# 45.0    1
# 34.0    1
# Name: age, dtype: int64

# %% [markdown]
# In North-east Region:
#
# Most people who smoke are of age between 18 and 35.

# %%
G111['sex_female'].value_counts()
# Out:
# 0    38
# 1    29
# Name: sex_female, dtype: int64

# %% [markdown]
# In North-east Region:
#
# Most people who smoke are male.

# %%
pd.crosstab(G111.sex_male, G111.age,values=G111.charges,aggfunc=np.average,margins=True)
# Out:
# age               18.0         20.0  ...        63.0           All
# sex_male                             ...
# 0         14283.459400          NaN  ...  29523.1656  28032.046398
# 1         21270.786242  33475.81715  ...         NaN  30926.252583
# All       20272.596693  33475.81715  ...  29523.1656  29673.536473
#
# [3 rows x 38 columns]

# %% [markdown]
# In North-east Region:
#
# Average charges of smokers age-wise.

# %% [markdown]
# Region-Northwest

# %% [markdown]
# Total Population:323
#
# smokers:58
#
# non-smokers:265

# %%
H=edf.groupby(['region_northwest'])

# %%
G2=H.get_group(1)

# %% [markdown]
# Taking only North-west people into a separate Dataset(G2)

# %%
svG2=G2.sort_values(['charges'],ascending=False)
svG2[['charges','age','sex_male','smoker_yes']].head(60)
# Out:
#                 charges   age  sex_male  smoker_yes
# patient_id
# 1230        60021.39897  52.0         1           1
# 819         55135.40209  33.0         0           1
# 56          47496.49445  58.0         1           1
# 1301        46718.16325  62.0         1           1
# 1122        46661.44240  53.0         0           1
# 677         46130.52650  60.0         1           1
# 570         45702.02235  48.0         1           1
# 587         43943.87610  34.0         0           1
# 257         43921.18370  56.0         1           1
# 87          43578.93940  57.0         0           1
# 629         42983.45850  44.0         0           1
# 328         42760.50220  45.0         1           1
# 147         40720.55105  46.0         1           1
# 667         40003.33225  40.0         0           1
# 559         39983.42595  35.0         0           1
# 1037        39725.51805  45.0         0           1
# 299         38746.35510  31.0         1           1
# 1139        36898.73308  19.0         0           1
# 264         36219.40545  19.0         1           1
# 1093        33907.54800  22.0         0           1
# 260         33750.29180  19.0         1           1
# 599         33471.97189  52.0         0           0
# 1196        33307.55080  19.0         0           1
# 641         32787.45859  42.0         1           1
# 129         32734.18630  32.0         0           1
# 388         30284.64294  50.0         1           0
# 63          30166.61817  64.0         1           0
# 1258        30063.58055  55.0         1           0
# 890         29330.98315  64.0         0           1
# 1337        29141.36030  61.0         0           1
# 420         28950.46920  63.0         0           1
# 10          28923.13692  60.0         0           0
# 476         28868.66390  61.0         1           1
# 806         28476.73499  40.0         0           0
# 959         28468.91901  48.0         1           0
# 987         28340.18885  45.0         0           0
# 964         26467.09737  52.0         1           0
# 445         26109.32905  56.0         1           1
# 1019        26018.95052  21.0         0           0
# 607         25678.77845  59.0         0           1
# 1007        24915.22085  47.0         1           1
# 1281        24535.69855  47.0         0           1
# 246         24476.47851  54.0         1           0
# 332         24393.62240  52.0         1           1
# 527         24059.68019  19.0         0           0
# 966         23967.38305  51.0         1           1
# 1176        23887.66270  52.0         0           1
# 546         23807.24060  49.0         1           1
# 1039        22493.65964  19.0         1           0
# 4           21984.47061  33.0         1           0
# 1045        21880.82000  43.0         0           1
# 916         21774.32215  43.0         0           1
# 1030        21677.28345  46.0         0           1
# 1027        21595.38229  23.0         1           0
# 1307        21472.47880  32.0         1           1
# 161         21348.70600  42.0         0           1
# 86          21098.55405  45.0         1           1
# 145         20745.98910  30.0         1           1
# 1040        20234.85475  35.0         0           1
# 954         20009.63365  34.0         1           1

# %% [markdown]
# In the North-west Region
#
# High charges are for people who smoke
#
# And there are some people who do not smoke but have high charges.

# %%
G2['smoker_yes'].value_counts()
# Out:
# 0    265
# 1     58
# Name: smoker_yes, dtype: int64

# %% [markdown]
# In North-west Region:
#
# 58 people smoke out of 265.

# %%
G22=G2.groupby('smoker_yes')

# %%
G222=G22.get_group(1)

# %% [markdown]
# Taking only smoking people from North-west region to a separate dataframe(G222)

# %%
G222['children'].value_counts()
# Out:
# 0    24
# 3    13
# 2    11
# 1     9
# 4     1
# Name: children, dtype: int64

# %% [markdown]
# In North-west Region:
#
# Out of 58 people who smoke:
#
# 24 people have no children
#
# 13 people have 3 children
#
# 11 people have 2 children
#
# 9 people have  1 child
#
# 1 people have 4 children

# %%
G222['age'].value_counts()
# Out:
# 19.0    8
# 20.0    3
# 52.0    3
# 45.0    3
# 30.0    3
# 35.0    2
# 46.0    2
# 34.0    2
# 56.0    2
# 42.0    2
# 27.0    2
# 32.0    2
# 43.0    2
# 47.0    2
# 61.0    2
# 63.0    1
# 57.0    1
# 31.0    1
# 23.0    1
# 62.0    1
# 49.0    1
# 53.0    1
# 48.0    1
# 59.0    1
# 44.0    1
# 40.0    1
# 60.0    1
# 33.0    1
# 25.0    1
# 64.0    1
# 51.0    1
# 22.0    1
# 58.0    1
# Name: age, dtype: int64

# %% [markdown]
# Most people who smoke are of age 19

# %%
G222['sex_female'].value_counts()
# Out:
# 1    29
# 0    29
# Name: sex_female, dtype: int64

# %% [markdown]
# In North-west Region:
#
# Equal number of males and equal number of females smoke.

# %%
pd.crosstab(G222.sex_male, G222.age,values=G222.charges,aggfunc=np.average,margins=True)
# Out:
# age               19.0          20.0  ...         64.0           All
# sex_male                              ...
# 0         26355.943495  14711.743800  ...  29330.98315  29670.824946
# 1         25943.318063  15410.698888  ...          NaN  29878.549498
# All       26149.630779  15177.713859  ...  29330.98315  29774.687222
#
# [3 rows x 34 columns]

# %% [markdown]
# In North-west Region:
#
# Average charges of smokers age-wise.

# %% [markdown]
# Region-southwest

# %% [markdown]
# Total Population:324
#
# Smokers = 57
#
# non-smokers=267

# %%
I=edf.groupby(['region_southwest'])

# %%
G3=I.get_group(1)

# %% [markdown]
# Taking only South-west Region people to a separate Dataframe(G3)

# %%
svG3=G3.sort_values(['charges'],ascending=False)
svG3[['charges','age','sex_male','smoker_yes']].head(60)
# Out:
#                 charges   age  sex_male  smoker_yes
# patient_id
# 1146        52590.82939  60.0         1           1
# 35          51194.55914  28.0         1           1
# 176         48824.45000  63.0         0           1
# 40          48173.36100  60.0         1           1
# 329         47928.03000  64.0         0           1
# 1284        47403.88000  61.0         1           1
# 252         47305.30500  63.0         0           1
# 95          47291.05500  64.0         0           1
# 739         44585.45587  29.0         1           1
# 272         42856.83800  50.0         1           1
# 1218        41661.60200  46.0         0           1
# 621         40182.24600  37.0         1           1
# 682         40103.89000  39.0         1           1
# 85          39836.51900  37.0         0           1
# 1049        39727.61400  49.0         1           1
# 609         39241.44200  30.0         1           1
# 953         38998.54600  44.0         1           1
# 30          38711.00000  31.0         1           1
# 1207        38415.47400  36.0         1           1
# 1288        38344.56600  20.0         1           1
# 1303        37829.72420  43.0         1           1
# 442         37079.37200  33.0         0           1
# 1206        36910.60803  59.0         0           0
# 20          36837.46700  30.0         1           1
# 1313        36397.57600  19.0         0           1
# 501         36197.69900  29.0         1           1
# 374         36085.21900  26.0         1           1
# 31          35585.57600  22.0         1           1
# 323         35491.64000  34.0         1           1
# 243         35160.13457  55.0         0           0
# 315         34838.87300  27.0         0           1
# 1291        34828.65400  19.0         1           1
# 224         34779.61500  19.0         1           1
# 1001        34472.84100  24.0         1           1
# 1120        34166.27300  23.0         0           1
# 1308        33900.65300  25.0         0           1
# 770         27941.28758  61.0         1           0
# 688         26236.57997  47.0         0           0
# 876         26140.36030  49.0         0           0
# 475         25382.29700  54.0         1           1
# 1053        25309.48900  47.0         1           1
# 356         24603.04837  46.0         1           0
# 783         24520.26400  50.0         0           1
# 53          23568.27200  48.0         1           1
# 617         23306.54700  49.0         1           1
# 431         23082.95533  19.0         1           0
# 1171        22478.60000  43.0         0           1
# 462         22144.03200  42.0         1           1
# 456         21797.00040  59.0         1           0
# 1003        21232.18226  48.0         1           0
# 515         21082.16000  39.0         1           1
# 46          20630.28351  55.0         1           0
# 1104        20420.60465  37.0         1           0
# 307         20177.67113  28.0         0           0
# 1231        20167.33603  20.0         0           1
# 949         19933.45800  25.0         1           1
# 982         19199.94400  31.0         1           1
# 762         19040.87600  33.0         1           1
# 1085        19023.26000  39.0         0           1
# 341         18955.22017  24.0         0           0

# %% [markdown]
# In the South-west Region
#
# High charges are for people who smoke
#
# And there are some people who do not smoke but have high charges.

# %%
G3['smoker_yes'].value_counts()
# Out:
# 0    267
# 1     57
# Name: smoker_yes, dtype: int64

# %% [markdown]
# In South-west Region:
#
# out of 324 people 57 people are smokers.

# %%
G33=G3.groupby('smoker_yes')

# %%
G333=G33.get_group(1)

# %% [markdown]
# Taking only Smokers from South-west region to a separate Dataframe(G333)

# %%
G333['children'].value_counts()
# Out:
# 0    25
# 2    16
# 1     8
# 3     5
# 4     2
# 5     1
# Name: children, dtype: int64

# %% [markdown]
# Out of 57 people who smoke:
#
# 25 people have no children
#
# 16 people have 2 children
#
# 8 people have 1 child
#
# 5 people have 3 children
#
# 2 people have 4 children
#
# 1 people have 5 children

# %%
G333['age'].value_counts()
# Out:
# 19.0    7
# 30.0    3
# 20.0    3
# 39.0    3
# 29.0    2
# 31.0    2
# 60.0    2
# 37.0    2
# 64.0    2
# 63.0    2
# 50.0    2
# 36.0    2
# 33.0    2
# 49.0    2
# 43.0    2
# 25.0    2
# 21.0    1
# 24.0    1
# 46.0    1
# 22.0    1
# 28.0    1
# 23.0    1
# 48.0    1
# 47.0    1
# 38.0    1
# 54.0    1
# 44.0    1
# 27.0    1
# 34.0    1
# 26.0    1
# 32.0    1
# 42.0    1
# 61.0    1
# Name: age, dtype: int64

# %% [markdown]
# In South-west Region:
#
# Most people who smoke are of age 19

# %%
G333['sex_female'].value_counts()
# Out:
# 0    37
# 1    20
# Name: sex_female, dtype: int64

# %% [markdown]
# In South-west Region:
#
# out of 57 people who smoke:
#
# 37 are male
#
# 20 are female

# %%
pd.crosstab(G333.sex_male, G333.age,values=G333.charges,aggfunc=np.average,margins=True)
# Out:
# age               19.0          20.0  ...        64.0           All
# sex_male                              ...
# 0         21052.021500  20167.336030  ...  47609.5425  30966.712302
# 1         28635.371667  27288.706500  ...         NaN  32598.862854
# All       24302.028714  24914.916343  ...  47609.5425  32026.178450
#
# [3 rows x 34 columns]

# %% [markdown]
# In South-West Region:
#
# Charges of people who smoke in South-west Region.

# %% [markdown]
# Region-Southeast

# %% [markdown]
# Total Population:359
#
# Smokers = 90
#
# non-smokers=269

# %%
J=edf.groupby(['region_southeast'])

# %%
G4=J.get_group(1)

# %% [markdown]
# Taking only people of South-east region into a separate DataFrame(G4).

# %%
svG4=G4.sort_values(['charges'],ascending=False)
svG4[['charges','age','sex_male','smoker_yes']].head(60)
# Out:
#                 charges   age  sex_male  smoker_yes
# patient_id
# 1300        62592.87309  45.0         1           1
# 1241        49577.66240  64.0         1           1
# 1062        48970.24760  59.0         1           1
# 489         48885.13561  44.0         0           1
# 531         48675.51770  57.0         1           1
# 901         48673.55880  60.0         1           1
# 951         47462.89400  51.0         1           1
# 1240        47269.85400  52.0         1           1
# 110         47055.53210  63.0         1           1
# 421         46889.26120  64.0         1           1
# 422         46599.10840  61.0         1           1
# 674         46200.98510  44.0         0           1
# 266         46151.12450  46.0         1           1
# 550         45863.20500  43.0         0           1
# 845         45008.95550  60.0         0           1
# 1031        44423.80300  55.0         0           1
# 706         44400.40640  51.0         0           1
# 253         44260.74990  54.0         1           1
# 893         44202.65360  47.0         1           1
# 1323        43896.37630  42.0         0           1
# 826         43813.86610  56.0         1           1
# 615         42969.85270  47.0         0           1
# 665         42560.43040  43.0         1           1
# 1022        42211.13820  47.0         1           1
# 313         42124.51530  43.0         1           1
# 293         42112.23560  25.0         1           1
# 956         41999.52000  54.0         1           1
# 1111        41949.24410  38.0         1           1
# 1090        41676.08110  47.0         1           1
# 856         40974.16490  48.0         0           1
# 1152        40941.28540  43.0         0           1
# 725         40932.42950  30.0         0           1
# 736         40419.01910  37.0         0           1
# 697         40273.64550  41.0         1           1
# 1070        39871.70430  37.0         1           1
# 1156        39722.74620  19.0         1           1
# 15          39611.75770  27.0         1           1
# 803         38792.68560  18.0         0           1
# 50          38709.17600  36.0         1           1
# 1118        38282.74950  33.0         1           1
# 525         38245.59327  42.0         1           1
# 378         38126.24650  24.0         1           1
# 54          37742.57570  36.0         1           1
# 1036        37484.44930  22.0         1           1
# 83          37165.16380  22.0         1           1
# 204         37133.89820  27.0         0           1
# 159         36950.25670  30.0         1           1
# 1012        36580.28216  61.0         0           0
# 759         36307.79830  18.0         1           1
# 162         36149.48350  18.0         0           1
# 1117        36124.57370  25.0         1           1
# 842         36021.01120  23.0         0           1
# 1021        35595.58980  22.0         0           1
# 689         34806.46770  27.0         1           1
# 1078        34672.14720  28.0         1           1
# 618         34439.85590  19.0         0           1
# 58          34303.16720  18.0         1           1
# 504         32548.34050  19.0         1           1
# 104         30942.19180  61.0         0           1
# 444         28287.89766  59.0         0           0

# %% [markdown]
# In the South-east Region
#
# High charges are for people who smoke.

# %%
G4['smoker_yes'].value_counts()
# Out:
# 0    269
# 1     90
# Name: smoker_yes, dtype: int64

# %% [markdown]
# Out of 350 people ,90 people smoke.

# %%
G44=G4.groupby('smoker_yes')

# %%
G444=G44.get_group(1)

# %% [markdown]
# Taking only Smokers of South-east region to a separate Dataframe(G444)

# %%
G444['children'].value_counts()
# Out:
# 0    41
# 1    21
# 2    17
# 3    11
# Name: children, dtype: int64

# %% [markdown]
# Out of 90 people who smoke:
#
# 41 people have no children
#
# 21 people have 1 children
#
# 17 people have 2 children
#
# 11 people have 3 children

# %%
G444['age'].value_counts()
# Out:
# 47.0    6
# 27.0    5
# 18.0    5
# 43.0    5
# 64.0    4
# 37.0    3
# 48.0    3
# 22.0    3
# 51.0    3
# 19.0    3
# 30.0    3
# 42.0    3
# 52.0    2
# 44.0    2
# 57.0    2
# 40.0    2
# 20.0    2
# 54.0    2
# 23.0    2
# 60.0    2
# 61.0    2
# 28.0    2
# 53.0    2
# 36.0    2
# 25.0    2
# 39.0    1
# 29.0    1
# 63.0    1
# 34.0    1
# 24.0    1
# 46.0    1
# 45.0    1
# 41.0    1
# 35.0    1
# 56.0    1
# 32.0    1
# 55.0    1
# 59.0    1
# 38.0    1
# 33.0    1
# 31.0    1
# 26.0    1
# 62.0    1
# Name: age, dtype: int64

# %% [markdown]
# Most people who smoke in this region are of age above 30.

# %%
G444['sex_female'].value_counts()
# Out:
# 0    55
# 1    35
# Name: sex_female, dtype: int64

# %% [markdown]
# Out of 90 people who smoke:
#
# 55 are male
#
# 35 are female

# %%
pd.crosstab(G444.sex_male, G444.age,values=G444.charges,aggfunc=np.average,margins=True)
# Out:
# age               18.0         19.0  ...          64.0           All
# sex_male                             ...
# 0         31055.206767  34439.85590  ...  27037.914100  32156.660508
# 1         35305.482750  36135.54335  ...  41131.146000  35461.832454
# All       32755.317160  35570.31420  ...  37607.838025  34176.487809
#
# [3 rows x 44 columns]

# %% [markdown]
# In South-east Region:
#
# Charges of people who smoke in South-west Region.

# %%
pd.crosstab(edf.sex_male,edf.smoker_yes,values=edf.charges,aggfunc=np.average)
# Out:
# smoker_yes            0             1
# sex_male
# 0           8761.069043  30249.563122
# 1           8114.735047  32693.297133

# %% [markdown]
# **Hypothesis:**

# %% [markdown]
# :
#
# Irrespective of region and Gender
#
# people who smoke are having high charges compared to people who don't smoke.

# %% [markdown]
# And people who smoke are of age group 18-35 in most regions.

# %% [markdown]
# And some people are having High charges even though they do not smoke.
#
# Those people are having high Charges because
#
# Either:
#
# they are old and have lot of health issues.
#
# And have Some other disability or health issues.

# %% [markdown]
# #Hypothesis testing

# %% [markdown]
# ## Our claim is that the   charges for smokers are greaterthan average of all patients

# %% [markdown]
# ###t_test with out p value

# %%
data.head()
# Out:
#              age     sex     bmi  children smoker     region      charges
# patient_id
# 1           19.0  female  27.900         0    yes  southwest  16884.92400
# 2           18.0    male  33.770         1     no  southeast   1725.55230
# 3           28.0    male  33.000         3     no  southeast   4449.46200
# 4           33.0    male  22.705         0     no  northwest  21984.47061
# 5           32.0    male  28.880         0     no  northwest   3866.85520

# %%
data['smoker'].value_counts()
# Out:
# no     1063
# yes     275
# Name: smoker, dtype: int64

# %%
max(data[data['smoker']=="no"]['charges'])
# Out:
# 36910.60803

# %%
smoker=data.loc[data.smoker=="yes"]
smoker.head()
# Out:
#              age     sex    bmi  children smoker     region     charges
# patient_id
# 1           19.0  female  27.90         0    yes  southwest  16884.9240
# 12          62.0  female  26.29         0    yes  southeast  27808.7251
# 15          27.0    male  42.13         0    yes  southeast  39611.7577
# 20          30.0    male  35.30         0    yes  southwest  36837.4670
# 24          34.0  female  31.92         1    yes  northeast  37701.8768

# %%
Non_smoker=data.loc[data.smoker=="no"]
Non_smoker.head()
# Out:
#              age     sex     bmi  children smoker     region      charges
# patient_id
# 2           18.0    male  33.770         1     no  southeast   1725.55230
# 3           28.0    male  33.000         3     no  southeast   4449.46200
# 4           33.0    male  22.705         0     no  northwest  21984.47061
# 5           32.0    male  28.880         0     no  northwest   3866.85520
# 6           31.0  female  25.740         0     no  southeast   3756.62160

# %%
data
# Out:
#              age     sex        bmi  children smoker     region       charges
# patient_id
# 1           19.0  female  27.900000         0    yes  southwest  16884.924000
# 2           18.0    male  33.770000         1     no  southeast   1725.552300
# 3           28.0    male  33.000000         3     no  southeast   4449.462000
# 4           33.0    male  22.705000         0     no  northwest  21984.470610
# 5           32.0    male  28.880000         0     no  northwest   3866.855200
# ...          ...     ...        ...       ...    ...        ...           ...
# 1335        18.0  female  36.850000         0     no  southeast   1629.833500
# 1336        21.0  female  25.800000         0     no  southwest   2007.945000
# 1337        61.0  female  29.070000         0    yes  northwest  29141.360300
# 1338        39.0    male  30.675161         0    yes  southeast  13261.018027
# 582         39.0    male  45.430000         2     no  southeast   6356.270700
#
# [1338 rows x 7 columns]

# %%
smoker
# Out:
#              age     sex        bmi  children smoker     region       charges
# patient_id
# 1           19.0  female  27.900000         0    yes  southwest  16884.924000
# 12          62.0  female  26.290000         0    yes  southeast  27808.725100
# 15          27.0    male  42.130000         0    yes  southeast  39611.757700
# 20          30.0    male  35.300000         0    yes  southwest  36837.467000
# 24          34.0  female  31.920000         1    yes  northeast  37701.876800
# ...          ...     ...        ...       ...    ...        ...           ...
# 1314        30.0  female  23.655000         3    yes  northwest  18765.875450
# 1321        62.0    male  26.695000         0    yes  northeast  28101.333050
# 1323        42.0  female  40.370000         2    yes  southeast  43896.376300
# 1337        61.0  female  29.070000         0    yes  northwest  29141.360300
# 1338        39.0    male  30.675161         0    yes  southeast  13261.018027
#
# [275 rows x 7 columns]

# %%
sample_smoker=smoker.sample(25)
sample_smoker.head()
# Out:
#              age   sex    bmi  children smoker     region     charges
# patient_id
# 885         32.0  male  28.93         1    yes  southeast  19719.6947
# 70          28.0  male  23.98         3    yes  southeast  17663.1442
# 31          22.0  male  35.60         0    yes  southwest  35585.5760
# 958         43.0  male  34.96         1    yes  northeast  41034.2214
# 689         27.0  male  31.13         1    yes  southeast  34806.4677

# %%
sample_mean=sample_smoker['charges'].mean()
sample_mean
# Out:
# 27503.1194612

# %%
mean_x=data['charges'].mean()
mean_x
# Out:
# 13261.018026877993

# %%
sample_std=sample_smoker['charges'].std()

# %%
alpha=0.05
n=25
degrees_of_freedom=n-1

# %%
t = (sample_mean - mean_x)/(sample_std / np.sqrt(n))
t
# Out:
# 6.286336319734028

# %%
t_critical = st.t.ppf(1-alpha, degrees_of_freedom)
t_critical
# Out:
# 1.7108820799094275

# %%
if (abs(t) > abs(t_critical)): #Absolute value taken as the it's a one-tailed test and the original t_critical value might be negative
    print("Null hypothesis cannot be rejected")
else:
    print("Reject null hypothesis")
# Out:
# Null hypothesis cannot be rejected

# %% [markdown]
# ## Our claim is lessthan average charges of all the smokers

# %% [markdown]
# ###z-test with p value

# %%
min(Non_smoker['age'])
# Out:
# 18.0

# %%
region=data.loc[data.region=="northwest"]
region.head()
# Out:
#              age     sex     bmi  children smoker     region      charges
# patient_id
# 4           33.0    male  22.705         0     no  northwest  21984.47061
# 5           32.0    male  28.880         0     no  northwest   3866.85520
# 8           37.0  female  27.740         3     no  northwest   7281.50560
# 10          60.0  female  25.840         0     no  northwest  28923.13692
# 25          37.0    male  28.025         2     no  northwest   6203.90175

# %%
sample_region=region.sample(60)
sample_region.head()
# Out:
#              age     sex     bmi  children smoker     region      charges
# patient_id
# 1113        28.0  female  26.315         3     no  northwest   5312.16985
# 994         27.0  female  20.045         3    yes  northwest  16420.49455
# 816         24.0  female  24.225         0     no  northwest   2842.76075
# 63          64.0    male  24.700         1     no  northwest  30166.61817
# 1157        23.0  female  23.180         2     no  northwest  14426.07385

# %%
sample_mean1=sample_region['charges'].mean()
sample_mean1
# Out:
# 12596.860407833334

# %%
mean_x1=smoker['charges'].mean()
mean_x1
# Out:
# 31893.891687795473

# %%
std1=smoker['charges'].std()
std1
# Out:
# 11626.112695652026

# %%
alpha = 0.05
n = 60

# %%
z = (sample_mean1-mean_x1)/(std1/np.sqrt(n))
z
# Out:
# -12.856761797343905

# %%
p_val = (st.norm.cdf(abs(z))) * 2
p_val
# Out:
# 2.0

# %%
if (p_val > alpha):
    print("Null hypothesis cannot be rejected")
else:
    print("Reject null hypothesis")
# Out:
# Null hypothesis cannot be rejected

# %%
data[(data['age'] > 60) & (data['age'] <= 64)]
# Out:
#              age     sex     bmi  children smoker     region      charges
# patient_id
# 12          62.0  female  26.290         0    yes  southeast  27808.72510
# 27          63.0  female  23.085         0     no  northeast  14451.83515
# 34          63.0    male  28.310         0     no  northwest  13770.09790
# 37          62.0  female  32.965         3     no  northwest  15612.19335
# 63          64.0    male  24.700         1     no  northwest  30166.61817
# ...          ...     ...     ...       ...    ...        ...          ...
# 1301        62.0    male  30.875         3    yes  northwest  46718.16325
# 1321        62.0    male  26.695         0    yes  northeast  28101.33305
# 1322        62.0    male  38.830         0     no  southeast  12981.34570
# 1325        61.0    male  33.535         0     no  northeast  13143.33665
# 1337        61.0  female  29.070         0    yes  northwest  29141.36030
#
# [91 rows x 7 columns]

# %%
li=[0]*len(data)
data['senior_citizen']=li

# %%
data.head()
# Out:
#              age     sex     bmi  ...     region      charges senior_citizen
# patient_id                        ...
# 1           19.0  female  27.900  ...  southwest  16884.92400              0
# 2           18.0    male  33.770  ...  southeast   1725.55230              0
# 3           28.0    male  33.000  ...  southeast   4449.46200              0
# 4           33.0    male  22.705  ...  northwest  21984.47061              0
# 5           32.0    male  28.880  ...  northwest   3866.85520              0
#
# [5 rows x 8 columns]

# %%
ind=data[(data['age']>60) & (data['age']<=64)]['senior_citizen'].index.values

# %%
for i in ind:
  data.loc[i,'senior_citizen']=1
data['senior_citizen'].value_counts()
# Out:
# 0    1247
# 1      91
# Name: senior_citizen, dtype: int64

# %%
df['senior_citizen']=data['senior_citizen']

# %% [markdown]
# #Feature Engineering

# %% [markdown]
# ##Oversampling

# %%
from imblearn.over_sampling import SMOTE

# %%
# import library
from imblearn.over_sampling import SMOTE

smote = SMOTE()
x,y=df.drop('senior_citizen',axis=1),df['senior_citizen']
# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(x, y)

print('Original dataset shape', Counter(y))
print('Resample dataset shape', Counter(y_smote))
x_smote
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-231-0cffaf6964bb> in <module>()
#       7 x_smote, y_smote = smote.fit_resample(x, y)
#       8
# ----> 9 print('Original dataset shape', Counter(y))
#      10 print('Resample dataset shape', Counter(y_smote))
#      11 x_smote
#
# NameError: name 'Counter' is not defined

# %%
balanced_df=x_smote

# %%
balanced_df.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_female', 'sex_male',
#        'region_northeast', 'region_northwest', 'region_southeast',
#        'region_southwest', 'smoker_no', 'smoker_yes'],
#       dtype='object')

# %%
balanced_df['senior_citizen']=np.array(y_smote)
balanced_df.head()
# Out:
#     age     bmi  children  ...  smoker_no  smoker_yes  senior_citizen
# 0  19.0  27.900         0  ...          0           1               0
# 1  18.0  33.770         1  ...          1           0               0
# 2  28.0  33.000         3  ...          1           0               0
# 3  33.0  22.705         0  ...          1           0               0
# 4  32.0  28.880         0  ...          1           0               0
#
# [5 rows x 13 columns]

# %%
balanced_df.loc[balanced_df['bmi']<25, 'weight_class'] = '1'

balanced_df.loc[(balanced_df['bmi']<30) & (balanced_df['bmi']>=25), 'weight_class'] = '2'

balanced_df.loc[(balanced_df['bmi']<40) & (balanced_df['bmi']>=30), 'weight_class'] = '3'

balanced_df.loc[balanced_df['bmi']>=40, 'weight_class'] = '4'

# %%
balanced_df.loc[(balanced_df['age']<31) & (balanced_df['age']>=18), 'age_group'] = '1'

balanced_df.loc[(balanced_df['age']<51) & (balanced_df['age']>=31), 'age_group'] = '2'

balanced_df.loc[balanced_df['age']>=51, 'age_group'] = '3'

# %%
balanced_df
# Out:
#             age        bmi  children  ...  senior_citizen  weight_class  age_group
# 0     19.000000  27.900000         0  ...               0             2          1
# 1     18.000000  33.770000         1  ...               0             3          1
# 2     28.000000  33.000000         3  ...               0             3          1
# 3     33.000000  22.705000         0  ...               0             1          2
# 4     32.000000  28.880000         0  ...               0             2          2
# ...         ...        ...       ...  ...             ...           ...        ...
# 2471  61.937625  38.698508         0  ...               1             3          3
# 2472  61.195796  35.730774         0  ...               1             3          3
# 2473  62.142919  28.309959         0  ...               1             2          3
# 2474  61.000000  39.082527         0  ...               1             3          3
# 2475  62.901195  35.854514         0  ...               1             3          3
#
# [2476 rows x 15 columns]

# %%
len(balanced_df.columns)
# Out:
# 15

# %% [markdown]
# #Feature Selection

# %%
# %matplotlib inline

# %%
t_df=balanced_df.drop('charges',axis=1)

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor =t_df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
l=correlation(t_df,0.7)

# %%
t_df.drop(l,axis=1)

# %%
l
# Out:
# {'senior_citizen', 'smoker_yes'}

# %%
t_df['charges']=balanced_df['charges']

# %% [markdown]
# #Test and Train

# %%
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from yellowbrick.regressor import PredictionError
from sklearn.neural_network import MLPRegressor
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor

# %%
y = t_df.charges
X = t_df.drop(["charges"], axis = 1)

# %%
test_size = 0.2
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = test_size, random_state = 20)

# %%
print("X_train shape {}, len {}.".format(X_train.shape,len(X_train)))
print("X_test shape {}, len {}.".format(X_test.shape,len(X_test)))
print("Y_train shape {}, len {}.".format(Y_train.shape,len(Y_train)))
print("Y_test shape {}, len {}.".format(Y_test.shape,len(Y_test)))
# Out:
# X_train shape (1980, 14), len 1980.
# X_test shape (496, 14), len 496.
# Y_train shape (1980,), len 1980.
# Y_test shape (496,), len 496.

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train) 
X_test = scaler.transform(X_test)

# %%
result = []

# %% [markdown]
# #Linear Regression

# %%
multiple_linear = LinearRegression()
multiple_linear.fit(X_train, Y_train)
predict = multiple_linear.predict(X_test)
score = r2_score(Y_test,predict)
result.append(score)

# %%
print("r_square score --> ",score)
print('Mean Absolute Error -->', metrics.mean_absolute_error(Y_test, predict))
print('Mean Squared Error -->', metrics.mean_squared_error(Y_test, predict))
print('Root Mean Squared Error -->', np.sqrt(metrics.mean_squared_error(Y_test, predict)))
# Out:
# r_square score -->  0.8063377671814418
# Mean Absolute Error --> 3690.9739477677417
# Mean Squared Error --> 27929871.227345396
# Root Mean Squared Error --> 5284.87192156493

# %%
df_linearRegression = pd.DataFrame({'Actual': Y_test, 'Predicted': predict})
df_linearRegression.head()
# Out:
#             Actual     Predicted
# 694    2020.552300   3822.108168
# 2419  12967.752670  14554.680606
# 458   22144.032000  34342.961547
# 534    8825.086000  12168.176041
# 2168  14328.990188  13161.449830

# %%
visualizer = PredictionError(multiple_linear)
visualizer.fit(X_train, Y_train)  
visualizer.score(X_test, Y_test)        
visualizer.show();

# %% [markdown]
# #RandomForest

# %%
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

rf_param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
rf = RandomForestRegressor()
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = rf_param_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
rf_random.fit(X_train, Y_train)
rf_predict = rf_random.predict(X_test)
score_rf = r2_score(Y_test,rf_predict)
result.append(score_rf)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /usr/local/lib/python3.7/dist-packages/joblib/externals/loky/process_executor.py:705: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning

# %%
print("r_square score --> ",score_rf)
print('Mean Absolute Error -->', metrics.mean_absolute_error(Y_test, rf_predict))
print('Mean Squared Error -->', metrics.mean_squared_error(Y_test, rf_predict))
print('Root Mean Squared Error -->', np.sqrt(metrics.mean_squared_error(Y_test, rf_predict)))
# Out:
# r_square score -->  0.913065168936627
# Mean Absolute Error --> 1713.9943047877528
# Mean Squared Error --> 12537698.246234186
# Root Mean Squared Error --> 3540.8612294516975

# %%
df_RandomForestRegressor = pd.DataFrame({'Actual': Y_test, 'Predicted': rf_predict})
df_RandomForestRegressor.head()
# Out:
#             Actual     Predicted
# 694    2020.552300   3777.551342
# 2419  12967.752670  13251.368533
# 458   22144.032000  33336.721986
# 534    8825.086000   9058.247401
# 2168  14328.990188  14426.142637

# %%
visualizer = PredictionError(rf_random)
visualizer.fit(X_train, Y_train)  
visualizer.score(X_test, Y_test)        
visualizer.show();

# %% [markdown]
# #KNN

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, Y_train)
knn_predict = knn.predict(X_test)
score_knn = r2_score(Y_test,knn_predict)
result.append(score_knn)

# %%
print("r_square score --> ",score_knn)
print('Mean Absolute Error -->', metrics.mean_absolute_error(Y_test, knn_predict))
print('Mean Squared Error -->', metrics.mean_squared_error(Y_test, knn_predict))
print('Root Mean Squared Error -->', np.sqrt(metrics.mean_squared_error(Y_test, knn_predict)))
# Out:
# r_square score -->  0.894411860141947
# Mean Absolute Error --> 1956.522434002418
# Mean Squared Error --> 15227869.194988208
# Root Mean Squared Error --> 3902.290249967089

# %%
df_KNNRegressor = pd.DataFrame({'Actual': Y_test, 'Predicted': knn_predict})
df_KNNRegressor.head()
# Out:
#             Actual     Predicted
# 694    2020.552300   4306.164590
# 2419  12967.752670  13002.716704
# 458   22144.032000  29928.419840
# 534    8825.086000   8395.951000
# 2168  14328.990188  14021.055084

# %%
visualizer = PredictionError(knn)
visualizer.fit(X_train, Y_train)  
visualizer.score(X_test, Y_test)        
visualizer.show();

# %% [markdown]
# ##MLP##

# %%
parameter_mlp = {
    'hidden_layer_sizes': [(50,50,50), (50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
    'max_iter':[400, 500],
}

# %%
model = MLPRegressor()
clf = GridSearchCV(model, parameter_mlp, n_jobs=-1, cv=3)
clf.fit(X_train,Y_train)
mlp_predict = clf.predict(X_test)
score_mlp = r2_score(Y_test,mlp_predict)
result.append(score_mlp)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [ 3.91787115e-01 -1.77021965e+00  3.18105071e-01 -1.76275442e+00
#   3.31869307e-01 -1.77033548e+00  5.46551595e-01 -1.76286225e+00
#   4.00835573e-01 -1.77021113e+00  5.28062746e-01 -1.76257446e+00
#   3.86101603e-01 -1.77018171e+00  3.29422914e-01 -1.76260320e+00
#   5.34170638e-01 -1.77038368e+00  4.33246018e-01 -1.76280861e+00
#   4.14320538e-01 -1.77035860e+00  3.80877477e-01 -1.76293500e+00
#   8.23628267e-01 -1.73158513e+00  8.17347136e-01 -1.71609278e+00
#   8.28236911e-01 -1.73137649e+00  8.45167574e-01 -1.71617199e+00
#   1.79715961e-01 -1.77024761e+00  2.27212978e-01 -1.76259018e+00
#   3.71436010e-01 -1.77029572e+00  4.22913882e-01 -1.76276798e+00
#   1.88258206e-01 -1.77029916e+00  1.20762203e-01 -1.76275219e+00
#   2.97401406e-01 -1.77030022e+00  1.83952507e-01 -1.76256812e+00
#   2.46578464e-01 -1.77036149e+00  1.50693064e-01 -1.76285670e+00
#   2.84280112e-01 -1.77045306e+00  2.04975277e-01 -1.76293850e+00
#   8.13572647e-01 -1.73172416e+00  8.44065503e-01 -1.71606588e+00
#   8.44384352e-01 -1.73188989e+00  8.44932428e-01 -1.71616897e+00
#              nan  8.92714390e-01             nan  8.96305527e-01
#              nan  8.92437926e-01 -8.99172476e+60  8.94493908e-01
#  -3.59452433e+82  8.93295609e-01             nan  8.96845726e-01
#              nan  8.93238495e-01             nan  8.96893556e-01
#              nan  8.94370748e-01             nan  8.99767292e-01
#              nan  8.95775328e-01             nan  8.96093690e-01
#              nan -8.45697609e-01             nan -5.48112383e-01
#              nan -8.27118209e-01             nan -5.06668876e-01
#              nan  8.92752515e-01             nan  8.96056881e-01
#             -inf  8.91988906e-01             nan  8.96762869e-01
#              nan  8.93048000e-01             nan  8.98063472e-01
#              nan  8.93774246e-01             nan  8.97157485e-01
#              nan  8.95092620e-01             nan  8.97392546e-01
#              nan  8.95559891e-01             nan  8.97813428e-01
#              nan -8.44359900e-01             nan -5.60442073e-01
#              nan -8.55211292e-01             nan -5.06603767e-01]
#   category=UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:978: RuntimeWarning: invalid value encountered in subtract
#   (array - array_means[:, np.newaxis]) ** 2, axis=1, weights=weights
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,

# %%
print("r_square score --> ",score_mlp)
print('Mean Absolute Error -->', metrics.mean_absolute_error(Y_test, mlp_predict))
print('Mean Squared Error -->', metrics.mean_squared_error(Y_test, mlp_predict))
print('Root Mean Squared Error -->', np.sqrt(metrics.mean_squared_error(Y_test, mlp_predict)))
# Out:
# r_square score -->  0.9023693373751807
# Mean Absolute Error --> 1900.4372928260807
# Mean Squared Error --> 14080245.772578454
# Root Mean Squared Error --> 3752.3653570219485

# %%
df_MLPRegressor = pd.DataFrame({'Actual': Y_test, 'Predicted': mlp_predict})
df_MLPRegressor.head()
# Out:
#             Actual     Predicted
# 694    2020.552300   3562.850712
# 2419  12967.752670  13084.272431
# 458   22144.032000  37551.342988
# 534    8825.086000   9742.385113
# 2168  14328.990188  14284.168547

# %%
visualizer = PredictionError(clf)
visualizer.fit(X_train, Y_train)  
visualizer.score(X_test, Y_test)        
visualizer.show();
